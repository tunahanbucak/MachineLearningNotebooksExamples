# %%
my_name="tuna"

# %%
my_name_upper = my_name.upper()

# %%
my_name_upper
# Out:
# 'TUNA'

# %%
# functions

# %%
def hello_python():
    print("hello")
    print("python")

# %%
hello_python()
# Out:
# hello
# python

# %%
#input

# %%
def hello_name(name):
    print("hello")
    print(name)

# %%
hello_name("tunahan")
# Out:
# hello
# tunahan

# %%
def sum_example(num1,num2):
    print(num1+num2)

# %%
sum_example(5,15)
# Out:
# 20

# %%
def hello_surname(surname="buçak"):
    print("hello")
    print(surname)

# %%
hello_surname()
# Out:
# hello
# buçak

# %%
hello_surname("asd")
# Out:
# hello
# asd

# %%
#return

# %%
def return_summation(num1,num2,num3):
    result = num1+num2+num3
    print(result)
    return result

# %%
x = return_summation(15,17,20)
# Out:
# 52

# %%
x
# Out:
# 52

# %%
def control_string(s):
    if s[0] == "a":
        print("bu kelime a harfi ile başlıyor")

# %%
control_string("arabaaaa")
# Out:
# bu kelime a harfi ile başlıyor

# %%
#args, kwargs (arguments, key word arguments)

# %%
# birnde fazla argüman almak için

# %%
def args_sum(*args):
    return sum(args)

# %%
args_sum(12,5612,53432,21321,)
# Out:
# 80377

# %%
args_sum(123,23)
# Out:
# 146

# %%
def kwargs_example(**kwargs):
    print(kwargs)

# %%
kwargs_example(apple=100,banana=400,melon=123)
# Out:
# {'apple': 100, 'banana': 400, 'melon': 123}

# %%
def kwargs_example2(**kwargs):
    if "apple" in kwargs:
        print("elma var burdaaaaaa")
    else:
        print(":(((((((")

# %%
kwargs_example2(apple=10,banana=20)
# Out:
# elma var burdaaaaaa

# %%
kwargs_example2(melon=10,banana=20)
# Out:
# :(((((((
