# %%
class Person():
   #property
    #python da propertyleri yazmama gerek yok, yazılmadığında da o özellikleirn olduğunu anlar
   # name=""
   # age=0
   # gender=""
    #zorunlu olamyan için burda belirtebilriiz
    job=""

    # initializer method
    def __init__(self,name,age,gender):
        self.name= name
        self.age= age
        self.gender= gender

    #self kullanmak gerekiyor sıınıf içindeki methodlarda
    #method
    def test(self):
        print("testtest")

    def printName(self):
        print(self.name)

# %%
tuna = Person("Tuna",22,"Male")

# %%
type(tuna)
# Out:
# __main__.Person

# %%
tuna.age
# Out:
# 22

# %%
tuna.gender
# Out:
# 'Male'

# %%
tuna.name
# Out:
# 'Tuna'

# %%
tuna.test()
# Out:
# testtest

# %%
tuna.printName()
# Out:
# Tuna

# %%
tuna.job
# Out:
# ''

# %%
tuna.job="developer"

# %%
tuna.job
# Out:
# 'developer'

# %%
class Dog():
    year = 7
    def __init__(self,age):
        self.age = age
      # ya bunun içinde belirterek yaparız ya da ayrı bi method yazarız
        self.dogHumanAge = age * self.year

    # ayrı method
    def humanAge(self):
        return self.age * self.year # Dog.year == sef.year

# %%
myDog= Dog(5)

# %%
myDog.age
# Out:
# 5

# %%
myDog.humanAge()
# Out:
# 35

# %%
myDog.dogHumanAge
# Out:
# 35
