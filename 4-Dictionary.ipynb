# %%
# key -value pairing

# %%
fruitList=["banana","apple"]

# %%
calorieList=[100,150]

# %%
calorieList[0]
# Out:
# 100

# %%
fruitList[0]
# Out:
# 'banane'

# %%
fitnesDictionary={"banana":100,"apple":150}

# %%
type(fitnesDictionary)
# Out:
# dict

# %%
fitnesDictionary["banana"
]
# Out:
# 100

# %%
fitnesDictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitnesDictionary.values()
# Out:
# dict_values([100, 150])

# %%
type(fitnesDictionary.values())
# Out:
# dict_values

# %%
list(fitnesDictionary.values())
# Out:
# [100, 150]

# %%
fitnesDictionary["melon"] = 300

# %%
fitnesDictionary
# Out:
# {'banana': 100, 'apple': 150, 'melon': 300}

# %%
fitnesDictionary.get("apple",0)
# Out:
# 150

# %%
#eğer listede o istenen yoksa defauult değer igösterir

# %%
fitnesDictionary.get("appl",0)
# Out:
# 0

# %%
myMixedDictionary= {"key1":100,"key2":3.14,"key3":[10,20,30]}

# %%
myMixedDictionary["key3"]
# Out:
# [10, 20, 30]

# %%
myMixedDictionary["key3"][2]
# Out:
# 30

# %%
lastDictionary={"k1":10,"k2":[10,20,30,40],"k3":"string","k4":{"a":100,"b":200}}

# %%
lastDictionary["k4"]["b"]
# Out:
# 200

# %%
lastDictionary["k2"][3]
# Out:
# 40
