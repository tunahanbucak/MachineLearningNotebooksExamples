# %%
# list

# %%
myList = [10,20,30,]

# %%
myList.append(80) # listeye ekleme yapar

# %%
myList
# Out:
# [10, 20, 30, 80]

# %%
myList.count(20)
# Out:
# 1

# %%
myList.insert(2,35) #2.index e 35 ekler

# %%
myList
# Out:
# [10, 20, 35, 30, 80]

# %%
myList.remove(80) # siler

# %%
myList
# Out:
# [10, 20, 35, 30]

# %%
myList.reverse() # sondan sıralar

# %%
myList
# Out:
# [30, 35, 20, 10]

# %%
myList.sort() #küçükten sıralar

# %%
myList
# Out:
# [10, 20, 30, 35]

# %%
x = input("enter x:")
# Out:
# enter x: 15

# %%
y = input("enter y:")
# Out:
# enter y: 10

# %%
z = input("enter z:")
# Out:
# enter z: 67

# %%
inputList = []

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['15', '10', '67']

# %%
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
int(inputList[2] ) + 10
# Out:
# 77

# %%
myNestedList = [10.19,16,'tuna',[1,2,3,]]

# %%
myNestedList # liste içinde liste tutabiliriz
# Out:
# [10.19, 16, 'tuna', [1, 2, 3]]

# %%
myNestedList[2]
# Out:
# 'tuna'

# %%
myNestedList[-1]
# Out:
# [1, 2, 3]

# %%
# liste içindeki listenin herhabgi bi indexine erişmek için

# %%
myNestedList[-1][2]
# Out:
# 3
