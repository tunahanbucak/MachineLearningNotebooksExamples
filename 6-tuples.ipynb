# %%
myList = [10,"a","b",3.15]

# %%
myList[2]
# Out:
# 'b'

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 'a', 'b', 3.15]

# %%
# tuple

# %%
myTuple = (10,"a","b",3.15)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0]
# Out:
# 10

# %%
 # myTuple[0] = 100 bu çalışmaz
