# %%
age = input("enter age:")
# Out:
# enter age: 22

# %%
age
# Out:
# '22'

# %%
int(age)*2
# Out:
# 44

# %%
# try - except

# %%
while True:
    try:
        myAge = int(input("enter age:"))
        print(myAge * 2)
        break
    except:
        print("enter your age !!!!!!!!!!!")
# Out:
# enter age: tuna
# enter your age !!!!!!!!!!!
# enter age: 22
# 44
