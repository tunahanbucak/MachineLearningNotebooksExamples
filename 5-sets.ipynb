# %%
 # unique elements, unordered

# %%
myList = [10,39,40,25,10,20,30,10]

# %%
mySet = set(myList)

# %%
mySet
# Out:
# {10, 20, 25, 30, 39, 40}

# %%
mySet.add(50)

# %%
mySet
# Out:
# {10, 20, 25, 30, 39, 40, 50}

# %%
mySet2 = [10,20,40,50]

# %%
# birleştir , aynı olanlar 1 defa yazılır setlerde

# %%
mySet.union(mySet2)
# Out:
# {10, 20, 25, 30, 39, 40, 50}

# %%
# ortak olanları bulmak için

# %%
mySet.intersection(mySet2)
# Out:
# {10, 20, 40, 50}

# %%
countryList = ["tr","en","fr","tr","de","de","en","tr"]

# %%
len(countryList)
# Out:
# 8

# %%
set(countryList)
# Out:
# {'de', 'en', 'fr', 'tr'}

# %%
len(set(countryList))
# Out:
# 4
