# %%
# true false

# %%
3 > 5
# Out:
# False

# %%
5> 8
# Out:
# False

# %%
5> 4
# Out:
# True

# %%
age = input("yaş giriniz:")
# Out:
# yaş giriniz: 22

# %%
age
# Out:
# '22'

# %%
# bu hata verir çünkü age bi string

# %%
 # age > 15

# %%
 int(age)> 15
# Out:
# True
