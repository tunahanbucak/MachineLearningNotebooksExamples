# %%
mySuperHero = "Batman"

# %%
if mySuperHero == "Batman":
    print("batmannn")
    print("tunahan")
# Out:
# batmannn
# tunahan

# %%
myHero = input("enter hero:")
# Out:
# enter hero: adads

# %%
if myHero =="batman":
    print("Batman")
elif myHero == "ironman":
    print("İronman")

else :
    print(":(")
# Out:
# :(

# %%
myHeroo = input("enter hero:")
# Out:
# enter hero: spiderman

# %%
myHeroList = ["spiderman","batman","iron man"]

# %%
if myHeroo in myHeroList:
    print(":)")
else :
    print(":(")
# Out:
# :)
