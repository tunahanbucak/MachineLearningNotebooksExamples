# %%
"hello world"
# Out:
# 'hello world'

# %%
print("helloooo")
# Out:
# helloooo

# %%
name = "tunahan"

# %%
name.capitalize()
# Out:
# 'Tunahan'

# %%
name
# Out:
# 'tunahan'

# %%
name.count("a")
# Out:
# 2

# %%
name.upper()
# Out:
# 'TUNAHAN'

# %%
myname = name.upper()

# %%
myname
# Out:
# 'TUNAHAN'

# %%
name
# Out:
# 'tunahan'

# %%
len(name)  #length
# Out:
# 7

# %%
print("tunahan  buçak")
# Out:
# tunahan  buçak

# %%
print("tunahan \n buçak")
# Out:
# tunahan
#  buçak

# %% [markdown]
# İNDEX

# %%
myString = "hello python"

# %%
myString[4]
# Out:
# 'o'

# %%
myName = "james hetfield"

# %%
myName[len(myName)-1]
# Out:
# 'd'

# %%
myName[-1] # eksilerde sondan başlıyor
# Out:
# 'd'

# %%
myName[-2]
# Out:
# 'l'

# %%
# sliicng, starting index, stopping idndex, stepping size

# %%
barcode = "ABGDLKL13123DSFSD2"

# %%
# barcode[starting index : stopping index : stepping size(kaçar kaaçar ilerleme) ]

# %%
barcode[2:6:2]
# Out:
# 'GL'

# %%
barcode[3::]
# Out:
# 'DLKL13123DSFSD2'

# %%
barcode[:3:]
# Out:
# 'ABG'

# %%
barcode[3:5]
# Out:
# 'DL'

# %%
name = 'tunahan buçak'

# %%
name.index('a')
# Out:
# 3

# %%
name.split()
# Out:
# ['tunahan', 'buçak']

# %%
type(name.split())
# Out:
# list
